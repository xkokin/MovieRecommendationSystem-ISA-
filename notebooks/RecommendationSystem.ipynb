# %% [markdown]
# # Imports

# %%
import pandas as pd
import plotly.express as px
from sklearn.feature_extraction.text import TfidfVectorizer
import wikipedia
import numpy as np
from tqdm.notebook import tqdm
from tabulate import tabulate
import re
import os

from sklearn.metrics.pairwise import linear_kernel
from surprise import Dataset
from surprise import Reader
from surprise import SVD
from surprise import accuracy
from surprise import KNNBasic
from surprise import NormalPredictor
from surprise.model_selection import train_test_split
from nltk.stem.snowball import SnowballStemmer
from sklearn.feature_selection import VarianceThreshold
from surprise.model_selection import LeaveOneOut
import requests
from io import BytesIO
import nltk
from nltk.tag.stanford import StanfordNERTagger
import plotly.io as pio
import ipyplot

# %%
BASE_FOLDER = '..'
pio.renderers.default = "notebook_connected"
tqdm.pandas()

# %% [markdown]
# # EDA
#
#
# 3 Datasets, movies.dat, ratings.dat, users.dat, that are needed to be explored

# %% [markdown]
# ## Movies

# %%
movies_df = pd.read_csv(
    f"{BASE_FOLDER}/data/raw/movies.dat",
    delimiter="::",
    engine="python",
    header=None,
    names=["movie_name", "genre"],
    encoding="ISO-8859-1"
)
movies_df.head()
# Out:
#                            movie_name                         genre
# 1                    Toy Story (1995)   Animation|Children's|Comedy
# 2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 3             Grumpier Old Men (1995)                Comedy|Romance
# 4            Waiting to Exhale (1995)                  Comedy|Drama
# 5  Father of the Bride Part II (1995)                        Comedy

# %% [markdown]
# Check the distribution of movies by genres. Explode genres column, turn it to a list, hence some movies will be listed twice since they have multiple genres

# %%
movies_df['genre'] = movies_df['genre'].apply(lambda x: x.split('|'))
movies_df_exploded = movies_df.explode('genre')
px.histogram(movies_df_exploded, x='genre', height=400, title='Movie count by genre').update_xaxes(categoryorder="total descending")
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.0.1.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="38ab30b5-6cb9-484c-91db-85c1afda7e3c" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("38ab30b5-6cb9-484c-91db-85c1afda7e3c")) {                    Plotly.newPlot(                        "38ab30b5-6cb9-484c-91db-85c1afda7e3c",                        [{"bingroup":"x","hovertemplate":"genre=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":["Animation","Children's","Comedy","Adventure","Children's","Fantasy","Comedy","Romance","Comedy","Drama","Comedy","Action","Crime","Thriller","Comedy","Romance","Adventure","Children's","Action","Action","Adventure","Thriller","Comedy","Drama","Romance","Comedy","Horror","Animation","Children's","Drama","Action","Adventure","Romance","Drama","Thriller","Drama","Romance","Thriller","Comedy","Action","Action","Comedy","Drama","Crime","Drama","Thriller","Thriller","Drama","Sci-Fi","Drama","Romance","Drama","Drama","Romance","Adventure","Sci-Fi","Drama","Drama","Drama","Sci-Fi","Adventure","Romance","Children's","Comedy","Drama","Drama","Romance","Drama","Documentary","Comedy","Comedy","Romance","Drama","Drama","War","Action","Crime","Drama","Drama","Action","Adventure","Comedy","Drama","Drama","Romance","Crime","Thriller","Animation","Children's","Musical","Romance","Drama","Romance","Crime","Thriller","Action","Drama","Thriller","Comedy","Drama","Children's","Comedy","Drama","Adventure","Children's","Fantasy","Drama","Drama","Romance","Drama","Mystery","Adventure","Children's","Fantasy","Drama","Thriller","Drama","Comedy","Comedy","Romance","Comedy","Sci-Fi","Thriller","Drama","Comedy","Romance","Comedy","Action","Comedy","Crime","Horror","Thriller","Action","Comedy","Drama","Drama","Musical","Drama","Romance","Comedy","Drama","Sci-Fi","Thriller","Documentary","Drama","Drama","Thriller","Drama","Crime","Drama","Romance","Drama","Drama","Comedy","Drama","Drama","Romance","Adventure","Drama","Children's","Comedy","Comedy","Action","Thriller","Drama","Drama","Thriller","Comedy","Romance","Drama","Action","Thriller","Comedy","Drama","Action","Thriller","Documentary","Drama","Thriller","Comedy","Comedy","Thriller","Comedy","Drama","Romance","Comedy","Drama","Adventure","Children's","Comedy","Musical","Documentary","Comedy","Action","Drama","War","Drama","Thriller","Action","Adventure","Crime","Drama","Mystery","Drama","Comedy","Documentary","Crime","Comedy","Romance","Comedy","Drama","Drama","Comedy","Romance","Drama","Mystery","Romance","Drama","Comedy","Adventure","Children's","Fantasy","Drama","Documentary","Comedy","Romance","Drama","Drama","Romance","Thriller","Comedy","Drama","Documentary","Comedy","Documentary","Documentary","Drama","Action","Drama","Drama","Romance","Comedy","Drama","Drama","Comedy","Action","Adventure","Children's","Drama","Drama","Crime","Drama","Thriller","Drama","Drama","Romance","War","Horror","Action","Adventure","Comedy","Crime","Drama","Drama","War","Comedy","Comedy","War","Adventure","Children's","Drama","Action","Adventure","Mystery","Sci-Fi","Drama","Thriller","War","Documentary","Action","Romance","Thriller","Crime","Film-Noir","Mystery","Thriller","Action","Thriller","Comedy","Drama","Drama","Action","Adventure","Drama","Romance","Adventure","Children's","Drama","Action","Crime","Thriller","Comedy","Action","Sci-Fi","Thriller","Action","Adventure","Sci-Fi","Comedy","Drama","Comedy","Horror","Comedy","Drama","Romance","Comedy","Action","Children's","Drama","Romance","Thriller","Drama","Sci-Fi","Thriller","Comedy","Comedy","Horror","Comedy","Thriller","Drama","Documentary","Drama","Drama","Comedy","Drama","Romance","Horror","Sci-Fi","Drama","Ac ...

# %% [markdown]
# Dramas and Comedies are top movies genres, while westerns and noirs are for small groups of people. Drama can be western and noir, but not every western and noir is a drama or comedy.

# %%
movies_df['year'] = movies_df['movie_name'].apply(lambda movie_name: re.search('\((\d*)\)', movie_name).groups(1)[0])
movie_count_by_year = px.histogram(movies_df, x='year', height=400, title='Movie count by year').update_xaxes(categoryorder="total descending")
movie_count_by_year
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="1f2ef119-fe1e-49cd-9f73-18d8511ae758" class="plotly-graph-div" style="height:400px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("1f2ef119-fe1e-49cd-9f73-18d8511ae758")) {                    Plotly.newPlot(                        "1f2ef119-fe1e-49cd-9f73-18d8511ae758",                        [{"bingroup":"x","hovertemplate":"year=%{x}\u003cbr\u003ecount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"x":["1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1994","1995","1994","1995","1995","1995","1995","1994","1995","1995","1996","1995","1996","1996","1996","1996","1995","1995","1995","1996","1995","1995","1995","1996","1996","1995","1995","1995","1996","1995","1995","1995","1995","1995","1995","1996","1996","1996","1995","1995","1996","1995","1996","1996","1995","1995","1994","1995","1996","1996","1996","1996","1996","1995","1994","1996","1995","1995","1995","1976","1995","1996","1995","1995","1995","1995","1996","1995","1996","1993","1992","1994","1995","1996","1994","1994","1994","1995","1995","1995","1995","1995","1995","1996","1995","1995","1995","1995","1996","1996","1988","1995","1995","1995","1995","1995","1995","1994","1995","1995","1995","1995","1967","1995","1995","1994","1995","1995","1995","1995","1994","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1993","1995","1995","1995","1995","1994","1994","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1964","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1995","1994","1995","1994","1994","1995","1995","1995","1995","1995","1995","1995","1994","1995","1994","1995","1994","1995","1994","1994","1994","1994","1994","1994","1994","1995","1995","1995","1995","1995","1995","1994","1995","1995","1994","1994","1994","1994","1994","1994","1995","1994","1994","1995","1994","1994","1995","1995","1995","1977","1994","1995","1994","1994","1992","1994","1994","1994","1993","1994","1995","1994","1994","1995","1994","1994","1994","1995","1995","1995","1994","1994","1995","1996","1993","1995","1994","1994","1994","1994","1995","1995","1994","1995","1995","1994","1995","1992","1994","1994","1995","1994","1995","1995","1994","1994","1993","1994","1994","1995","1994","1995","1994","1994","1994","1994","1994","1994","1994","1993","1993","1995","1994","1995","1994","1995","1995","1994","1995","1994","1995","1995","1994","1995","1995","1993","1995","1995","1994","1994","1994","1995","1994","1994","1993","1992","1994","1994","1994","1994","1994","1994","1994","1994","1994","1994","1995","1994","1994","1994","1994","1993","1994","1993","1994","1994","1994","1994","1994","1994","1994","1992","1994","1994","1994","1994","1994","1994","1994","1994","1994","1994","1995","1994","1994","1994","1995","1994","1965","1994","1993","1994","1995","1995","1995","1995","1995","1995","1995","1995","1996","1995","1994","1994","1994","1995","1994","1994","1993","1994","1993","1994","1994","1993","1994","1994","1993","1993","1994","1994","1994","1994","1994","1994","1993","1993","1993","1994","1993","1993","1994","1994","1993","1993","1994","1994","1994","1993","1993","1993","1993","1994","1993","1993","1993","1994","1993","1993","1994","1993","1994","1993","1993","1993","1994","1993","1993","1994","1994","1994","1994","1993","1993","1993 ...

# %% [markdown]
# Obviously, the recent the year is - the more movies was produced due to progress

# %% [markdown]
# ## Users
#
# Lets take a look at occupations

# %%
readme_text = np.array(open(f'{BASE_FOLDER}/data/raw/README').read().splitlines())
start_index = np.flatnonzero(np.core.defchararray.find(readme_text,'Occupation is chosen')!=-1)[0]
end_index = np.flatnonzero(np.core.defchararray.find(readme_text,'MOVIES FILE DESCRIPTION')!=-1)[0]
occupation_list = [x.split('"')[1] for x in readme_text[start_index:end_index][2:-1].tolist()]
occupation_dict = dict(zip(range(len(occupation_list)), occupation_list))

users_df = pd.read_csv(f'{BASE_FOLDER}/data/raw/users.dat',
                       delimiter='::', engine='python', header=None,
                       names=['user_id', 'gender', 'age', 'occupation', 'zip_code'])
users_df['occupation'] = users_df['occupation'].replace(occupation_dict)
users_df.head()
# Out:
#    user_id gender  age            occupation zip_code
# 0        1      F    1          K-12 student    48067
# 1        2      M   56         self-employed    70072
# 2        3      M   25             scientist    55117
# 3        4      M   45  executive/managerial    02460
# 4        5      M   25                writer    55455

# %% [markdown]
# ## Ratings

# %%
ratings_df = pd.read_csv(f'{BASE_FOLDER}/data/raw/ratings.dat',
                         delimiter='::', engine='python', header=None,
                         names=['user_id', 'movie_id', 'rating', 'time'])
ratings_df.head()
# Out:
#    user_id  movie_id  rating       time
# 0        1      1193       5  978300760
# 1        1       661       3  978302109
# 2        1       914       3  978301968
# 3        1      3408       4  978300275
# 4        1      2355       5  978824291

# %% [markdown]
# Rank movie genres by their average rating

# %%
rating_by_genre_df = ratings_df.join(movies_df_exploded, on='movie_id').\
            groupby('genre').agg({'rating': ['mean', 'count']}).sort_values(('rating', 'mean')).reset_index()
rating_by_genre_df.columns = ['_'.join(col).strip() for col in rating_by_genre_df.columns.values]
px.bar(rating_by_genre_df, x='genre_', y='rating_mean', height=300)
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="e0349f8e-6e3a-4f08-ac82-af948490eca1" class="plotly-graph-div" style="height:300px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("e0349f8e-6e3a-4f08-ac82-af948490eca1")) {                    Plotly.newPlot(                        "e0349f8e-6e3a-4f08-ac82-af948490eca1",                        [{"hovertemplate":"genre_=%{x}\u003cbr\u003erating_mean=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Horror","Children's","Fantasy","Sci-Fi","Adventure","Action","Comedy","Thriller","Romance","Western","Musical","Mystery","Animation","Crime","Drama","War","Documentary","Film-Noir"],"xaxis":"x","y":{"dtype":"f8","bdata":"zoMw2li4CUBalWvAU2ALQCH98gg3lAtAV4nJg2+7C0DhBEcXbNELQIQ4Gl7y7QtAE9FzJkItDECr49+AUJAMQAGMSGYW3AxAzDxwPCcaDUBAORie+1INQDxaT9VFWA1ASQfwMJx6DUB8WfGnX6sNQB49HstyIQ5AymxxeoglD0C1uUn\u002fCHcPQAzenff9TBBA"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewi ...

# %% [markdown]
# It seems that people that are watching noirs are appreciating them the most since it is most rare genre...

# %% [markdown]
# ## Combine
#
# Check the differences between male and female ratings

# %%
combined_ratings_df = pd.merge(pd.merge(movies_df_exploded.rename_axis('movie_id'), ratings_df, on='movie_id'), users_df, on='user_id')
combined_ratings_data = combined_ratings_df.groupby(['genre', 'gender']).agg({'rating': ['mean', 'count']}).reset_index()
combined_ratings_data.columns = [' '.join(col).strip() for col in combined_ratings_data.columns.values]

combined_ratings_data.loc[combined_ratings_data['gender'] == 'F', 'rating count'] /= len(combined_ratings_df[combined_ratings_df['gender'] == 'F'])
combined_ratings_data.loc[combined_ratings_data['gender'] == 'M', 'rating count'] /= len(combined_ratings_df[combined_ratings_df['gender'] == 'M'])

px.bar(combined_ratings_data, x='genre', y='rating count', color='gender', barmode='group')
# Out:
# C:\Users\glebk\AppData\Local\Temp\ipykernel_17776\3203749018.py:5: FutureWarning:
#
# Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[0.09022863 0.05402254 0.02415518 0.0421337  0.19028258 0.03249812
#  0.00383447 0.19400242 0.01723139 0.00830538 0.02892653 0.02669305
#  0.01971787 0.09941356 0.05415694 0.07967    0.02785525 0.0068724 ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-3.0.1.min.js"></script>                <div id="52c6c476-f443-4eb2-81d8-c2443d67bb60" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("52c6c476-f443-4eb2-81d8-c2443d67bb60")) {                    Plotly.newPlot(                        "52c6c476-f443-4eb2-81d8-c2443d67bb60",                        [{"alignmentgroup":"True","hovertemplate":"gender=F\u003cbr\u003egenre=%{x}\u003cbr\u003erating count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"F","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"F","offsetgroup":"F","orientation":"v","showlegend":true,"textposition":"auto","x":["Action","Adventure","Animation","Children's","Comedy","Crime","Documentary","Drama","Fantasy","Film-Noir","Horror","Musical","Mystery","Romance","Sci-Fi","Thriller","War","Western"],"xaxis":"x","y":{"dtype":"f8","bdata":"ww7XIjkZtz9UjzGG16irP+5IKcgivJg\u002f5QPdhIySpT9HTegCLlvIP0hGcN6Xo6A\u002fIK5xJHdpbz80wJI2EtXIP9XiCU4bpZE\u002fvaz4fGkCgT+e0+5T6p6dP+mZgQtsVZs\u002fZ2hi2+swlD\u002fKpVzTKnO5P3sPgGB1uqs\u002fQxLExUBltD9lfhr4FYacP8FqfhA7Jnw\u002f"},"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"gender=M\u003cbr\u003egenre=%{x}\u003cbr\u003erating count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"textposition":"auto","x":["Action","Adventure","Animation","Children's","Comedy","Crime","Documentary","Drama","Fantasy","Film-Noir","Horror","Musical","Mystery","Romance","Sci-Fi","Thriller","War","Western"],"xaxis":"x","y":{"dtype":"f8","bdata":"yLu48QL9wD\u002fc3NroeRqxP1dQyVH875M\u002fgq6YsfNRoD9Ko8jq5eDEP1s92dlrPqQ\u002fhpu9qTWlbj\u002f5NvNoJJDEP06flhLfspE\u002fkHDjjsAKgj\u002ff+mw5tc+jP9Q3Nu\u002f3+5E\u002f5yuUnxNhkz9zaF18UzGvP3AdQ1Iz1rQ\u002f7qe+fRT2tz8uUvhEwHahP9qJV+mfFIY\u002f"},"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3 ...

# %% [markdown]
# # Preprocessing
#
#
# We will get data from the movies using wikipedia API (python package)

# %%
def get_wikipedia_page_name(raw_name):
    names = wikipedia.search(raw_name)
    if len(names) == 0:
      return ''
    else:
      return names[0]

def get_movie_plot(page_name):
    try:
      try:
        movie_page_content = str(wikipedia.page(page_name, auto_suggest=False).content)
      except wikipedia.DisambiguationError as e:
        for option in e.options:
          if 'film' in option:
            movie_page_content = str(wikipedia.page(option, auto_suggest=False).content)
        return ''
    except (wikipedia.PageError, KeyError):
      return ''
    re_groups = re.search("Plot ==(.*?)=+ [A-Z]", str(movie_page_content).replace('\n', ''))
    if re_groups:
      return re_groups.group(1)
    else:
      return ''

movies_df['wikipedia_page_name'] = movies_df['movie_name'].progress_apply(lambda name: get_wikipedia_page_name(name))
movies_df['movie_plot'] = movies_df['wikipedia_page_name'].progress_apply(lambda page_name: get_movie_plot(page_name))
print(f'There are {movies_df["movie_plot"].isna().sum()} NaN movie plots')
movies_df[['movie_name', 'movie_plot']].head()
# Out:
#   0%|          | 0/3883 [00:00<?, ?it/s]
# KeyboardInterrupt

# %% [markdown]
# Around 600 movies didn't have any plot on Wikipedia, this is not a big deal, so we will simply drop them out

# %%
movies_df = movies_df[~pd.isna(movies_df['movie_plot'])]
ratings_df = ratings_df[ratings_df['movie_id'].isin(movies_df.index)]

# %% [markdown]
# # Recommendation problem

# %% [markdown]
# Lets select test user that we will conduct our stdies on and then evaluate them

# %% [markdown]
# ## Intro

# %%
users_df.head()
# Out:
#    user_id gender  age            occupation zip_code
# 0        1      F    1          K-12 student    48067
# 1        2      M   56         self-employed    70072
# 2        3      M   25             scientist    55117
# 3        4      M   45  executive/managerial    02460
# 4        5      M   25                writer    55455

# %%
users_df.iloc[0,]
# Out:
# user_id                  1
# gender                   F
# age                      1
# occupation    K-12 student
# zip_code             48067
# Name: 0, dtype: object

# %% [markdown]
# We will also compare one movie during all reccomendation experiments and see what are the closest movies to it in embeddings.
#
# Let's conduc two dataset splits:
#
# 1. Standard: used for rating prediction
# 2. Leave-one-out cross validation split: used for hit-rate prediction, hit-rate is a suitable metric to evaluate effectiveness and accuracy of the system. Take one movie per user out of dataset and then use them as eval dataset. All remaining user's movies will be trainset, then hit-rate will be high each time top recommendated movie will be this one we lefr out.

# %%
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(ratings_df[['user_id', 'movie_id', 'rating']], reader)

unique_users = ratings_df['user_id'].unique()
selected_users = np.random.choice(unique_users, size=len(unique_users) // 2, replace=False)
filtered_ratings_df = ratings_df[ratings_df['user_id'].isin(selected_users)]
filtered_data = Dataset.load_from_df(filtered_ratings_df[['user_id', 'movie_id', 'rating']], reader)

trainset, testset = train_test_split(filtered_data, test_size=.25)
LOOCV = LeaveOneOut(n_splits=1, random_state=1)
train_loocv, test_loocv = list(LOOCV.split(filtered_data))[0]

# %% [markdown]
# For each method we will calculate:
#
# 1. RMSE on test set
# 2. hit-rate on leave-one-out cross validation set
# 3. Top predictions for user #1 (case study)
# 4. Top-10 most similar movies to Toy Story (1995)

# %% [markdown]
# ## Functions and Tools

# %%
from collections import defaultdict

def GetTopN(predictions, n=10, minimumRating=4.0):
  topN = defaultdict(list)

  for userID, movieID, actualRating, estimatedRating, _ in predictions:
    if (estimatedRating >= minimumRating):
        topN[userID].append((movieID, estimatedRating))

  for userID, ratings in topN.items():
    ratings.sort(key=lambda x: x[1], reverse=True)
    topN[userID] = ratings[:n]

  return topN

def HitRate(topNPredicted, leftOutPredictions):
  hits = 0
  total = 0

  # For each left-out rating
  for leftOut in leftOutPredictions:
    userID = leftOut[0]
    leftOutMovieID = leftOut[1]
    # Is it in the predicted top 10 for this user?
    hit = False
    for movieID, predictedRating in topNPredicted[userID]:
      if leftOutMovieID == movieID:
        hit = True
        break
    if (hit) :
      hits += 1

    total += 1

  # Compute overall precision
  return hits/total

def get_hitrate_results(algo, train_loocv, test_loocv):
  algo.fit(train_loocv)
  left_out_predictions = algo.test(test_loocv)
  loocv_anti_testset = train_loocv.build_anti_testset()
  all_predictions = algo.test(loocv_anti_testset)
  top_n_predicted = GetTopN(all_predictions)
  hitrate = HitRate(top_n_predicted, left_out_predictions)
  print(f'HitRate: {hitrate}')
  return all_predictions

def get_algo_results(algo, trainset, testset):
  algo.fit(trainset)
  predictions = algo.test(testset)
  accuracy.rmse(predictions)


def get_most_similar_movies(movies_df, movie_embeddings, trainset, target_movie_id, top_k=10):
    inner_movie_id = trainset.to_inner_iid(target_movie_id)
    sims = cosine_similarity(movie_embeddings, movie_embeddings)
    target_movie_sims_sorted = [trainset.to_raw_iid(x) for x in np.argsort(sims[inner_movie_id])[::-1]]
    most_similar_movies = movies_df.loc[target_movie_sims_sorted].iloc[:top_k]
    return most_similar_movies


def filter_predictions_for_user(predictions, user_id, movies_df, top_k=10):
    top_preds = sorted([pred for pred in predictions if pred.uid == user_id], key=lambda pred: pred.est, reverse=True)[:top_k]
    movie_ids = [pred.iid for pred in top_preds]
    relevant_movies = movies_df.loc[movie_ids]
    relevant_movies['rating'] = [pred.est for pred in top_preds]
    return relevant_movies


def get_algorithm_report(algo_class, trainset, testset, train_loocv, test_loocv, movies_df, target_movie_id=1, target_user_id=1, top_k=10, algo_args=[], algo_kwargs={}, calc_most_similar=True):
    algo_inst = algo_class(*algo_args, **algo_kwargs)
    get_algo_results(algo_inst, trainset, testset)
    algo_inst_for_hitrate = algo_class(*algo_args, **algo_kwargs)
    all_predictions = get_hitrate_results(algo_inst_for_hitrate, train_loocv, test_loocv)
    if calc_most_similar:
        if hasattr(algo_inst_for_hitrate, 'qi'):
            sims = algo_inst_for_hitrate.qi
        else:
            sims = algo_inst_for_hitrate.sim
        most_similar_movies = get_most_similar_movies(movies_df, sims, train_loocv, target_movie_id, top_k=top_k);
        print(f'Most similar movies to {movies_df.loc[target_movie_id].movie_name}:')
        print(tabulate(most_similar_movies.head(top_k)[['movie_name', 'genre']], headers='keys'))
    predictions_for_user = filter_predictions_for_user(all_predictions, target_user_id, movies_df)
    print(f'Top predictions for user {target_user_id}:')
    print(tabulate(predictions_for_user.head(top_k)[['movie_name', 'genre']], headers='keys'))


class SVDWithTqdm(SVD):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def test(self, testset, verbose=False):
        # The ratings are translated back to their original scale.
        predictions = [self.predict(uid,
                                    iid,
                                    r_ui_trans,
                                    verbose=verbose)
                        for (uid, iid, r_ui_trans) in tqdm(testset, desc='making predictions')]
        return predictions


class KNNBasicWithTqdm(KNNBasic):
    def __init__(self, *args, **kwargs):
        super().__init__(*args, **kwargs)

    def test(self, testset, verbose=False):
        # The ratings are translated back to their original scale.
        predictions = [self.predict(uid,
                                    iid,
                                    r_ui_trans,
                                    verbose=verbose)
                        for (uid, iid, r_ui_trans) in tqdm(testset, desc='making predictions')]
        return predictions

# %% [markdown]
# Lets obtain baseline for random recommendation system so we can later compaer how much our system is better.
#
# (Hit rate is a time complex computation process)

# %%
normal_predictor = NormalPredictor()
get_algo_results(normal_predictor, trainset, testset)
get_hitrate_results(normal_predictor, train_loocv, test_loocv)
# Out:
# RMSE: 1.5063
# HitRate: 0.015231788079470199
# [Prediction(uid=1, iid=1357, r_ui=3.58086904741548, est=4.4901512848370855, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3068, r_ui=3.58086904741548, est=3.8008886416455208, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1537, r_ui=3.58086904741548, est=4.033431976155324, details={'was_impossible': False}),
#  Prediction(uid=1, iid=647, r_ui=3.58086904741548, est=4.708134922900214, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2194, r_ui=3.58086904741548, est=3.3609757095729464, details={'was_impossible': False}),
#  Prediction(uid=1, iid=648, r_ui=3.58086904741548, est=2.667904255548537, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2268, r_ui=3.58086904741548, est=3.0663215394251555, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2628, r_ui=3.58086904741548, est=3.5352561958769617, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1103, r_ui=3.58086904741548, est=2.306425039892555, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2916, r_ui=3.58086904741548, est=2.3978358921529397, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3468, r_ui=3.58086904741548, est=4.297963113978573, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1210, r_ui=3.58086904741548, est=3.7967257203568767, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1792, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1687, r_ui=3.58086904741548, est=4.419999963502281, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1213, r_ui=3.58086904741548, est=4.415641475981067, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3578, r_ui=3.58086904741548, est=2.955524235007802, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2881, r_ui=3.58086904741548, est=4.167200294768756, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3030, r_ui=3.58086904741548, est=4.5179892425951085, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1217, r_ui=3.58086904741548, est=1.3802966987243561, details={'was_impossible': False}),
#  Prediction(uid=1, iid=434, r_ui=3.58086904741548, est=2.536392531957714, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2126, r_ui=3.58086904741548, est=4.5437761747607395, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3107, r_ui=3.58086904741548, est=2.648199914756958, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3108, r_ui=3.58086904741548, est=2.8944387214839917, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3035, r_ui=3.58086904741548, est=2.2244468001069246, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1253, r_ui=3.58086904741548, est=4.724768212891167, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1610, r_ui=3.58086904741548, est=1.6596935722349342, details={'was_impossible': False}),
#  Prediction(uid=1, iid=292, r_ui=3.58086904741548, est=2.8726661287862023, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2236, r_ui=3.58086904741548, est=3.911685257794065, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3071, r_ui=3.58086904741548, est=2.7111057635788964, details={'was_impossible': False}),
#  Prediction(uid=1, iid=902, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=368, r_ui=3.58086904741548, est=3.413797003203211, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1259, r_ui=3.58086904741548, est=3.9410359236464023, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3147, r_ui=3.58086904741548, est=1.8659236559146257, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1544, r_ui=3.58086904741548, est=3.2106768394235425, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1293, r_ui=3.58086904741548, est=1.9247413460951512, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1188, r_ui=3.58086904741548, est=3.970778320790735, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3255, r_ui=3.58086904741548, est=3.3791615544933893, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3256, r_ui=3.58086904741548, est=2.8555727455786792, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3257, r_ui=3.58086904741548, est=3.25786970010233, details={'was_impossible': False}),
#  Prediction(uid=1, iid=110, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2278, r_ui=3.58086904741548, est=4.853386645591435, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2490, r_ui=3.58086904741548, est=1.3684010265059667, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1834, r_ui=3.58086904741548, est=2.615543675581899, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3471, r_ui=3.58086904741548, est=2.9911883249212408, details={'was_impossible': False}),
#  Prediction(uid=1, iid=589, r_ui=3.58086904741548, est=1.3277636842067078, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1690, r_ui=3.58086904741548, est=4.785759026920061, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3654, r_ui=3.58086904741548, est=3.454634417947893, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2852, r_ui=3.58086904741548, est=3.7883579559646696, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1945, r_ui=3.58086904741548, est=4.729987513236679, details={'was_impossible': False}),
#  Prediction(uid=1, iid=982, r_ui=3.58086904741548, est=4.162972747351952, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1873, r_ui=3.58086904741548, est=2.6191062375723373, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2858, r_ui=3.58086904741548, est=3.524643195052055, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1225, r_ui=3.58086904741548, est=1.5527573447861562, details={'was_impossible': False}),
#  Prediction(uid=1, iid=515, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=442, r_ui=3.58086904741548, est=4.077670359583395, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2312, r_ui=3.58086904741548, est=3.195892135266243, details={'was_impossible': False}),
#  Prediction(uid=1, iid=265, r_ui=3.58086904741548, est=1.7758616590167449, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1408, r_ui=3.58086904741548, est=3.965489494660289, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1084, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3699, r_ui=3.58086904741548, est=3.2278205995121816, details={'was_impossible': False}),
#  Prediction(uid=1, iid=480, r_ui=3.58086904741548, est=4.71466778064696, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1442, r_ui=3.58086904741548, est=3.7438737501613057, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2067, r_ui=3.58086904741548, est=3.5105003863558455, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1265, r_ui=3.58086904741548, est=2.735773354553681, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1370, r_ui=3.58086904741548, est=4.154267290381627, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1801, r_ui=3.58086904741548, est=3.2651020155770585, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1372, r_ui=3.58086904741548, est=1.384061149691394, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2353, r_ui=3.58086904741548, est=2.864408544130658, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3334, r_ui=3.58086904741548, est=3.0609625546813097, details={'was_impossible': False}),
#  Prediction(uid=1, iid=590, r_ui=3.58086904741548, est=3.6600224268029633, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1196, r_ui=3.58086904741548, est=1.7994211269192677, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1552, r_ui=3.58086904741548, est=3.2811345400907457, details={'was_impossible': False}),
#  Prediction(uid=1, iid=736, r_ui=3.58086904741548, est=3.2111861479800488, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1198, r_ui=3.58086904741548, est=3.9243445872799283, details={'was_impossible': False}),
#  Prediction(uid=1, iid=593, r_ui=3.58086904741548, est=3.871493499201282, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2359, r_ui=3.58086904741548, est=2.6240162458432232, details={'was_impossible': False}),
#  Prediction(uid=1, iid=95, r_ui=3.58086904741548, est=4.7986848258817965, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2717, r_ui=3.58086904741548, est=3.2600400215760907, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2571, r_ui=3.58086904741548, est=4.120128995643862, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1917, r_ui=3.58086904741548, est=4.77593881372035, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2396, r_ui=3.58086904741548, est=2.121944705963638, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3735, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1953, r_ui=3.58086904741548, est=2.571303035186413, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1597, r_ui=3.58086904741548, est=4.7559100435881, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3809, r_ui=3.58086904741548, est=4.211044145328442, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1954, r_ui=3.58086904741548, est=2.6489595363913963, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1955, r_ui=3.58086904741548, est=3.2163204687459857, details={'was_impossible': False}),
#  Prediction(uid=1, iid=235, r_ui=3.58086904741548, est=4.325773759635564, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1124, r_ui=3.58086904741548, est=4.146126241990331, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1957, r_ui=3.58086904741548, est=3.3108444010553826, details={'was_impossible': False}),
#  Prediction(uid=1, iid=163, r_ui=3.58086904741548, est=4.420006187389137, details={'was_impossible': False}),
#  Prediction(uid=1, iid=21, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=165, r_ui=3.58086904741548, est=1.793034032743754, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1090, r_ui=3.58086904741548, est=1.671842077248321, details={'was_impossible': False}),
#  Prediction(uid=1, iid=380, r_ui=3.58086904741548, est=2.605721179803372, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2501, r_ui=3.58086904741548, est=3.2167863384457958, details={'was_impossible': False}),
#  Prediction(uid=1, iid=349, r_ui=3.58086904741548, est=2.2702324811657224, details={'was_impossible': False}),
#  Prediction(uid=1, iid=457, r_ui=3.58086904741548, est=3.6105460515355334, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1096, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=920, r_ui=3.58086904741548, est=4.587793276098713, details={'was_impossible': False}),
#  Prediction(uid=1, iid=459, r_ui=3.58086904741548, est=4.489946502854448, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1527, r_ui=3.58086904741548, est=3.5024325364604594, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3418, r_ui=3.58086904741548, est=3.723578454538968, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1385, r_ui=3.58086904741548, est=4.242382580951494, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3451, r_ui=3.58086904741548, est=4.749619062244413, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3095, r_ui=3.58086904741548, est=2.773261104882164, details={'was_impossible': False}),
#  Prediction(uid=1, iid=780, r_ui=3.58086904741548, est=4.368396878812942, details={'was_impossible': False}),
#  Prediction(uid=1, iid=498, r_ui=3.58086904741548, est=2.265872852226702, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2728, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2002, r_ui=3.58086904741548, est=4.0776564246937, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1784, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2943, r_ui=3.58086904741548, est=2.4289347161620323, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2006, r_ui=3.58086904741548, est=3.67647275305723, details={'was_impossible': False}),
#  Prediction(uid=1, iid=318, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1968, r_ui=3.58086904741548, est=4.663439939167999, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3678, r_ui=3.58086904741548, est=2.14175109041276, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1244, r_ui=3.58086904741548, est=4.551784304999772, details={'was_impossible': False}),
#  Prediction(uid=1, iid=356, r_ui=3.58086904741548, est=4.199366255320234, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1245, r_ui=3.58086904741548, est=2.3250846666655476, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3893, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1247, r_ui=3.58086904741548, est=2.368896838651488, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3421, r_ui=3.58086904741548, est=3.8647512407267834, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1641, r_ui=3.58086904741548, est=3.2489473245588396, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1394, r_ui=3.58086904741548, est=2.5561181721359274, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3534, r_ui=3.58086904741548, est=4.195690052034568, details={'was_impossible': False}),
#  Prediction(uid=1, iid=104, r_ui=3.58086904741548, est=2.697966417982384, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2735, r_ui=3.58086904741548, est=4.7640816498225345, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1431, r_ui=3.58086904741548, est=4.556475341825555, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1079, r_ui=3.58086904741548, est=4.054622189726122, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2997, r_ui=3.58086904741548, est=3.591766707800176, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1615, r_ui=3.58086904741548, est=2.7277372814342162, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1291, r_ui=3.58086904741548, est=1.6353954725451452, details={'was_impossible': False}),
#  Prediction(uid=1, iid=653, r_ui=3.58086904741548, est=3.2280056656501537, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2167, r_ui=3.58086904741548, est=3.6115046626589478, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1580, r_ui=3.58086904741548, est=3.145268528246187, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3619, r_ui=3.58086904741548, est=4.199527211400927, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1049, r_ui=3.58086904741548, est=3.53666670039623, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1261, r_ui=3.58086904741548, est=1.3035500904678265, details={'was_impossible': False}),
#  Prediction(uid=1, iid=552, r_ui=3.58086904741548, est=4.142769775913183, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1266, r_ui=3.58086904741548, est=2.8356747063111203, details={'was_impossible': False}),
#  Prediction(uid=1, iid=733, r_ui=3.58086904741548, est=4.791596032105314, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1378, r_ui=3.58086904741548, est=4.579951395071395, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1379, r_ui=3.58086904741548, est=2.7279560572218884, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3552, r_ui=3.58086904741548, est=3.8760982479379473, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1304, r_ui=3.58086904741548, est=4.959770511567406, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2470, r_ui=3.58086904741548, est=2.871178703185275, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3168, r_ui=3.58086904741548, est=1.7134423758042776, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2617, r_ui=3.58086904741548, est=4.029457367085101, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3671, r_ui=3.58086904741548, est=3.1053493792399833, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2871, r_ui=3.58086904741548, est=4.575348807566742, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2115, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1136, r_ui=3.58086904741548, est=3.5133038266400343, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2081, r_ui=3.58086904741548, est=3.61989693667104, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2951, r_ui=3.58086904741548, est=1.948064117641717, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1214, r_ui=3.58086904741548, est=4.333003371174403, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1036, r_ui=3.58086904741548, est=2.851997003359262, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3702, r_ui=3.58086904741548, est=4.275716585086929, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2366, r_ui=3.58086904741548, est=2.9477054409559758, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1387, r_ui=3.58086904741548, est=2.9376984673519253, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3527, r_ui=3.58086904741548, est=3.020326945964559, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1201, r_ui=3.58086904741548, est=2.2182499453149074, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2947, r_ui=3.58086904741548, est=4.576002242163647, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1240, r_ui=3.58086904741548, est=4.359666860608978, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2987, r_ui=3.58086904741548, est=4.205120985816083, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2333, r_ui=3.58086904741548, est=2.5478198269724386, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1175, r_ui=3.58086904741548, est=4.834640092283936, details={'was_impossible': False}),
#  Prediction(uid=1, iid=39, r_ui=3.58086904741548, est=3.520687130700963, details={'was_impossible': False}),
#  Prediction(uid=1, iid=288, r_ui=3.58086904741548, est=3.8543355362674223, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2337, r_ui=3.58086904741548, est=2.4828296891600012, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1535, r_ui=3.58086904741548, est=4.1311598231869056, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1392, r_ui=3.58086904741548, est=2.1406313235126553, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1466, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=860, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1683, r_ui=3.58086904741548, est=3.286443161574507, details={'was_impossible': False}),
#  Prediction(uid=1, iid=866, r_ui=3.58086904741548, est=3.721682170217317, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1684, r_ui=3.58086904741548, est=1.9420906879763, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2770, r_ui=3.58086904741548, est=2.9865326105413037, details={'was_impossible': False}),
#  Prediction(uid=1, iid=215, r_ui=3.58086904741548, est=2.8564430350134753, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1759, r_ui=3.58086904741548, est=2.3986497938846987, details={'was_impossible': False}),
#  Prediction(uid=1, iid=501, r_ui=3.58086904741548, est=2.36376508445203, details={'was_impossible': False}),
#  Prediction(uid=1, iid=506, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1250, r_ui=3.58086904741548, est=4.773548430664103, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3793, r_ui=3.58086904741548, est=4.1075522052944144, details={'was_impossible': False}),
#  Prediction(uid=1, iid=509, r_ui=3.58086904741548, est=3.3964830559882455, details={'was_impossible': False}),
#  Prediction(uid=1, iid=41, r_ui=3.58086904741548, est=4.538260812778889, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2058, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3799, r_ui=3.58086904741548, est=3.394360264407535, details={'was_impossible': False}),
#  Prediction(uid=1, iid=47, r_ui=3.58086904741548, est=4.0495301479044095, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2700, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=296, r_ui=3.58086904741548, est=4.882649267262513, details={'was_impossible': False}),
#  Prediction(uid=1, iid=581, r_ui=3.58086904741548, est=1.5505252983307263, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1617, r_ui=3.58086904741548, est=1.4079194630208751, details={'was_impossible': False}),
#  Prediction(uid=1, iid=728, r_ui=3.58086904741548, est=3.176288302974992, details={'was_impossible': False}),
#  Prediction(uid=1, iid=299, r_ui=3.58086904741548, est=2.697100715838817, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3079, r_ui=3.58086904741548, est=3.5923362482048655, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2560, r_ui=3.58086904741548, est=2.032970871456013, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1909, r_ui=3.58086904741548, est=2.218739683564719, details={'was_impossible': False}),
#  Prediction(uid=1, iid=224, r_ui=3.58086904741548, est=1.7681560401034317, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3728, r_ui=3.58086904741548, est=4.659803388783455, details={'was_impossible': False}),
#  Prediction(uid=1, iid=229, r_ui=3.58086904741548, est=1.853399198092367, details={'was_impossible': False}),
#  Prediction(uid=1, iid=6, r_ui=3.58086904741548, est=1.5915380462567743, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3006, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1046, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=800, r_ui=3.58086904741548, est=1.095196302744199, details={'was_impossible': False}),
#  Prediction(uid=1, iid=50, r_ui=3.58086904741548, est=2.2080199105071183, details={'was_impossible': False}),
#  Prediction(uid=1, iid=52, r_ui=3.58086904741548, est=1.6207627604496704, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1191, r_ui=3.58086904741548, est=3.973259067483497, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1192, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3081, r_ui=3.58086904741548, est=2.923631842152811, details={'was_impossible': False}),
#  Prediction(uid=1, iid=377, r_ui=3.58086904741548, est=4.392850918173888, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1268, r_ui=3.58086904741548, est=3.858187546176943, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3083, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2427, r_ui=3.58086904741548, est=2.6986054919718185, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3513, r_ui=3.58086904741548, est=3.5154776929156157, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2428, r_ui=3.58086904741548, est=2.2720922283534786, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2282, r_ui=3.58086904741548, est=1.7811928754582937, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3514, r_ui=3.58086904741548, est=4.195451671320993, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1554, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1912, r_ui=3.58086904741548, est=4.09007410793157, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2716, r_ui=3.58086904741548, est=4.122807633697957, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1485, r_ui=3.58086904741548, est=2.4635065854000318, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2289, r_ui=3.58086904741548, est=4.153847221800511, details={'was_impossible': False}),
#  Prediction(uid=1, iid=162, r_ui=3.58086904741548, est=2.3567093274666586, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1127, r_ui=3.58086904741548, est=4.087831921560076, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3016, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2070, r_ui=3.58086904741548, est=2.69982552912329, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1704, r_ui=3.58086904741548, est=4.131789152585864, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3163, r_ui=3.58086904741548, est=3.450540427087698, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2437, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2291, r_ui=3.58086904741548, est=3.440736854834829, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1635, r_ui=3.58086904741548, est=3.106609896796578, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1279, r_ui=3.58086904741548, est=4.587934876793431, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2721, r_ui=3.58086904741548, est=1.4709409170051893, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2723, r_ui=3.58086904741548, est=2.4107985051524246, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1921, r_ui=3.58086904741548, est=2.426526345073222, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2725, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1923, r_ui=3.58086904741548, est=3.2568422288808674, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2580, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3386, r_ui=3.58086904741548, est=2.916998554765452, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3744, r_ui=3.58086904741548, est=4.025698394684563, details={'was_impossible': False}),
#  Prediction(uid=1, iid=968, r_ui=3.58086904741548, est=3.701454410283618, details={'was_impossible': False}),
#  Prediction(uid=1, iid=896, r_ui=3.58086904741548, est=2.5110270896252636, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3020, r_ui=3.58086904741548, est=4.888770462605688, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1788, r_ui=3.58086904741548, est=3.983061386884441, details={'was_impossible': False}),
#  Prediction(uid=1, iid=176, r_ui=3.58086904741548, est=2.743135379352143, details={'was_impossible': False}),
#  Prediction(uid=1, iid=461, r_ui=3.58086904741548, est=4.560935253134473, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1429, r_ui=3.58086904741548, est=2.563562372800604, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2159, r_ui=3.58086904741548, est=4.685360293293087, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1715, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1643, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3249, r_ui=3.58086904741548, est=4.037084881249605, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3176, r_ui=3.58086904741548, est=3.7232411136099435, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1719, r_ui=3.58086904741548, est=3.2169844603946576, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2806, r_ui=3.58086904741548, est=1.032700368346506, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2734, r_ui=3.58086904741548, est=1.835538024716575, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1649, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=321, r_ui=3.58086904741548, est=3.75145755982949, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2013, r_ui=3.58086904741548, est=2.669146391496599, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3100, r_ui=3.58086904741548, est=3.031042271990445, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2952, r_ui=3.58086904741548, est=3.160477891022893, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1794, r_ui=3.58086904741548, est=4.056344888733641, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2599, r_ui=3.58086904741548, est=3.3657172567991482, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1500, r_ui=3.58086904741548, est=2.3882527079283875, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2959, r_ui=3.58086904741548, est=2.9911314955899866, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1509, r_ui=3.58086904741548, est=3.6402450797624413, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1722, r_ui=3.58086904741548, est=4.0173686055505184, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1650, r_ui=3.58086904741548, est=4.190486337337238, details={'was_impossible': False}),
#  Prediction(uid=1, iid=908, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1653, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2384, r_ui=3.58086904741548, est=3.035202412380351, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1729, r_ui=3.58086904741548, est=3.5106563712231877, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3476, r_ui=3.58086904741548, est=3.4836952378651405, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2890, r_ui=3.58086904741548, est=2.554080083817973, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3113, r_ui=3.58086904741548, est=3.6354064636338403, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2029, r_ui=3.58086904741548, est=2.963911951852962, details={'was_impossible': False}),
#  Prediction(uid=1, iid=194, r_ui=3.58086904741548, est=3.4654743159567913, details={'was_impossible': False}),
#  Prediction(uid=1, iid=551, r_ui=3.58086904741548, est=4.210109572994753, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1513, r_ui=3.58086904741548, est=1.8685903583706744, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3046, r_ui=3.58086904741548, est=3.9555877854063257, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2318, r_ui=3.58086904741548, est=2.3254555271217967, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1517, r_ui=3.58086904741548, est=3.585368665166364, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1089, r_ui=3.58086904741548, est=3.7820047150076106, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3260, r_ui=3.58086904741548, est=3.222677350855074, details={'was_impossible': False}),
#  Prediction(uid=1, iid=913, r_ui=3.58086904741548, est=3.517177072503608, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1730, r_ui=3.58086904741548, est=3.682847045087179, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3409, r_ui=3.58086904741548, est=4.179626325024019, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2607, r_ui=3.58086904741548, est=1.761444797683874, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1449, r_ui=3.58086904741548, est=4.464508273394753, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1732, r_ui=3.58086904741548, est=2.4414629205765954, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1733, r_ui=3.58086904741548, est=3.8693478420017113, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2390, r_ui=3.58086904741548, est=3.2909963036675896, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1734, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3266, r_ui=3.58086904741548, est=3.131798136199807, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3267, r_ui=3.58086904741548, est=3.5346267552664097, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3624, r_ui=3.58086904741548, est=3.3458215791427834, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2395, r_ui=3.58086904741548, est=2.7882046956569515, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1594, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2683, r_ui=3.58086904741548, est=2.5438903718661736, details={'was_impossible': False}),
#  Prediction(uid=1, iid=412, r_ui=3.58086904741548, est=2.137829442212084, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2759, r_ui=3.58086904741548, est=2.8374484294964892, details={'was_impossible': False}),
#  Prediction(uid=1, iid=994, r_ui=3.58086904741548, est=3.3053596081024432, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1884, r_ui=3.58086904741548, est=2.84156192930229, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1885, r_ui=3.58086904741548, est=4.128801910401109, details={'was_impossible': False}),
#  Prediction(uid=1, iid=272, r_ui=3.58086904741548, est=3.4048342764507304, details={'was_impossible': False}),
#  Prediction(uid=1, iid=24, r_ui=3.58086904741548, est=4.038814391434128, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3051, r_ui=3.58086904741548, est=3.822007116581136, details={'was_impossible': False}),
#  Prediction(uid=1, iid=348, r_ui=3.58086904741548, est=4.171194717668695, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2323, r_ui=3.58086904741548, est=3.7648940732626155, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1093, r_ui=3.58086904741548, est=4.48163822317624, details={'was_impossible': False}),
#  Prediction(uid=1, iid=29, r_ui=3.58086904741548, est=4.320322154828204, details={'was_impossible': False}),
#  Prediction(uid=1, iid=562, r_ui=3.58086904741548, est=3.887156070407365, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1095, r_ui=3.58086904741548, est=2.402253547096504, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1529, r_ui=3.58086904741548, est=2.5369955573319594, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2188, r_ui=3.58086904741548, est=3.3311550081055428, details={'was_impossible': False}),
#  Prediction(uid=1, iid=497, r_ui=3.58086904741548, est=3.0369933406732024, details={'was_impossible': False}),
#  Prediction(uid=1, iid=202, r_ui=3.58086904741548, est=3.221357070038837, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1747, r_ui=3.58086904741548, est=4.168286920244442, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2908, r_ui=3.58086904741548, est=4.4607008357686615, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1966, r_ui=3.58086904741548, est=3.554726428394536, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3499, r_ui=3.58086904741548, est=4.21919688676321, details={'was_impossible': False}),
#  Prediction(uid=1, iid=353, r_ui=3.58086904741548, est=4.367252703010799, details={'was_impossible': False}),
#  Prediction(uid=1, iid=32, r_ui=3.58086904741548, est=1.9931518019233756, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1243, r_ui=3.58086904741548, est=3.9105172599636884, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1897, r_ui=3.58086904741548, est=3.18421725381645, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1171, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3786, r_ui=3.58086904741548, est=3.9855453203942934, details={'was_impossible': False}),
#  Prediction(uid=1, iid=34, r_ui=3.58086904741548, est=1.1168037696695001, details={'was_impossible': False}),
#  Prediction(uid=1, iid=357, r_ui=3.58086904741548, est=3.698882273052475, details={'was_impossible': False}),
#  Prediction(uid=1, iid=36, r_ui=3.58086904741548, est=3.4584555150618383, details={'was_impossible': False}),
#  Prediction(uid=1, iid=714, r_ui=3.58086904741548, est=3.5993089542672796, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2406, r_ui=3.58086904741548, est=3.5491225011464698, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1101, r_ui=3.58086904741548, est=2.5768696938466764, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3717, r_ui=3.58086904741548, est=3.2176492220633963, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1030, r_ui=3.58086904741548, est=2.9094634918474447, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1688, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=364, r_ui=3.58086904741548, est=4.884505978970912, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3501, r_ui=3.58086904741548, est=1.3852221496651285, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3072, r_ui=3.58086904741548, est=4.843934360190047, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3074, r_ui=3.58086904741548, est=2.5318297883843335, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3508, r_ui=3.58086904741548, est=3.164649265535832, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1043, r_ui=3.58086904741548, est=3.342647295912266, details={'was_impossible': False}),
#  Prediction(uid=1, iid=597, r_ui=3.58086904741548, est=3.3332228388890393, details={'was_impossible': False}),
#  Prediction(uid=1, iid=383, r_ui=3.58086904741548, est=2.3835387508418657, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2506, r_ui=3.58086904741548, est=2.8123316370079694, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3524, r_ui=3.58086904741548, est=4.846791165077319, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1569, r_ui=3.58086904741548, est=2.8685072870645403, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2082, r_ui=3.58086904741548, est=4.225098683292085, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3600, r_ui=3.58086904741548, est=1.5427575422346052, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3604, r_ui=3.58086904741548, est=4.762530887653121, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2802, r_ui=3.58086904741548, est=3.44975313216678, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3536, r_ui=3.58086904741548, est=3.644114211549237, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3753, r_ui=3.58086904741548, est=2.6445745271764634, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3682, r_ui=3.58086904741548, est=3.744308488761363, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2017, r_ui=3.58086904741548, est=3.334190015368457, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3685, r_ui=3.58086904741548, est=2.8614129700128648, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3610, r_ui=3.58086904741548, est=3.506623355016196, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1296, r_ui=3.58086904741548, est=4.696240805097673, details={'was_impossible': False}),
#  Prediction(uid=1, iid=838, r_ui=3.58086904741548, est=3.7604660831086907, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1007, r_ui=3.58086904741548, est=3.17362381376929, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1947, r_ui=3.58086904741548, est=2.6135043570444765, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2966, r_ui=3.58086904741548, est=3.8471507524636035, details={'was_impossible': False}),
#  Prediction(uid=1, iid=266, r_ui=3.58086904741548, est=4.430137725535248, details={'was_impossible': False}),
#  Prediction(uid=1, iid=17, r_ui=3.58086904741548, est=1.9849582336340905, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1441, r_ui=3.58086904741548, est=3.990416754512612, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1088, r_ui=3.58086904741548, est=4.221484827365272, details={'was_impossible': False}),
#  Prediction(uid=1, iid=912, r_ui=3.58086904741548, est=3.851610017411439, details={'was_impossible': False}),
#  Prediction(uid=1, iid=199, r_ui=3.58086904741548, est=3.243422846899516, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1806, r_ui=3.58086904741548, est=3.382474935367977, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2469, r_ui=3.58086904741548, est=3.9054998787986617, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2100, r_ui=3.58086904741548, est=1.4342826141992155, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1959, r_ui=3.58086904741548, est=2.3126028472055564, details={'was_impossible': False}),
#  Prediction(uid=1, iid=569, r_ui=3.58086904741548, est=4.799728171250752, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1674, r_ui=3.58086904741548, est=4.271790092220346, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3565, r_ui=3.58086904741548, est=4.470026621955735, details={'was_impossible': False}),
#  Prediction(uid=1, iid=861, r_ui=3.58086904741548, est=2.884667322389676, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1997, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1573, r_ui=3.58086904741548, est=1.9508141162274748, details={'was_impossible': False}),
#  Prediction(uid=1, iid=474, r_ui=3.58086904741548, est=2.2009148431871797, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1221, r_ui=3.58086904741548, est=3.189851516306419, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2336, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3425, r_ui=3.58086904741548, est=2.943804117393377, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1393, r_ui=3.58086904741548, est=2.6528704282462447, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1682, r_ui=3.58086904741548, est=3.4012435291908445, details={'was_impossible': False}),
#  Prediction(uid=1, iid=508, r_ui=3.58086904741548, est=3.9068719887962264, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3213, r_ui=3.58086904741548, est=2.9288536399989624, details={'was_impossible': False}),
#  Prediction(uid=1, iid=42, r_ui=3.58086904741548, est=3.3353396078060635, details={'was_impossible': False}),
#  Prediction(uid=1, iid=650, r_ui=3.58086904741548, est=3.2513637103344206, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3500, r_ui=3.58086904741548, est=4.602773518957298, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3148, r_ui=3.58086904741548, est=3.4750754004968645, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2702, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1476, r_ui=3.58086904741548, est=4.87706389302062, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1693, r_ui=3.58086904741548, est=4.095181137232387, details={'was_impossible': False}),
#  Prediction(uid=1, iid=151, r_ui=3.58086904741548, est=3.1981813933904704, details={'was_impossible': False}),
#  Prediction(uid=1, iid=510, r_ui=3.58086904741548, est=4.198728421136946, details={'was_impossible': False}),
#  Prediction(uid=1, iid=4, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1621, r_ui=3.58086904741548, est=4.152335517871944, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3155, r_ui=3.58086904741548, est=3.0258364416388988, details={'was_impossible': False}),
#  Prediction(uid=1, iid=58, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2712, r_ui=3.58086904741548, est=2.9807886703926094, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2429, r_ui=3.58086904741548, est=4.754721119109298, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1840, r_ui=3.58086904741548, est=2.295532760302497, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1916, r_ui=3.58086904741548, est=2.909910189444255, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1488, r_ui=3.58086904741548, est=3.227928647081804, details={'was_impossible': False}),
#  Prediction(uid=1, iid=230, r_ui=3.58086904741548, est=2.994119997311074, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1120, r_ui=3.58086904741548, est=2.8505064903371164, details={'was_impossible': False}),
#  Prediction(uid=1, iid=161, r_ui=3.58086904741548, est=4.765626126150441, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1411, r_ui=3.58086904741548, est=4.323403324921244, details={'was_impossible': False}),
#  Prediction(uid=1, iid=524, r_ui=3.58086904741548, est=1.5194280193807361, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1059, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=454, r_ui=3.58086904741548, est=2.788454378813599, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1701, r_ui=3.58086904741548, est=3.0781528973787426, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1274, r_ui=3.58086904741548, est=2.4260652368396354, details={'was_impossible': False}),
#  Prediction(uid=1, iid=741, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1277, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1639, r_ui=3.58086904741548, est=2.5520553806287816, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3528, r_ui=3.58086904741548, est=3.462777366466802, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2297, r_ui=3.58086904741548, est=2.5585908603438847, details={'was_impossible': False}),
#  Prediction(uid=1, iid=465, r_ui=3.58086904741548, est=3.5764334389679493, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1711, r_ui=3.58086904741548, est=4.257939341005616, details={'was_impossible': False}),
#  Prediction(uid=1, iid=538, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=393, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2442, r_ui=3.58086904741548, est=2.6034672386518056, details={'was_impossible': False}),
#  Prediction(uid=1, iid=73, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3246, r_ui=3.58086904741548, est=3.4306757483710033, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3173, r_ui=3.58086904741548, est=4.558273864688136, details={'was_impossible': False}),
#  Prediction(uid=1, iid=105, r_ui=3.58086904741548, est=2.646668965838989, details={'was_impossible': False}),
#  Prediction(uid=1, iid=253, r_ui=3.58086904741548, est=4.401886859053981, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3250, r_ui=3.58086904741548, est=4.075047262876977, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3252, r_ui=3.58086904741548, est=2.968673726634063, details={'was_impossible': False}),
#  Prediction(uid=1, iid=476, r_ui=3.58086904741548, est=2.842408825636542, details={'was_impossible': False}),
#  Prediction(uid=1, iid=111, r_ui=3.58086904741548, est=2.4783521378419042, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3259, r_ui=3.58086904741548, est=2.265706614077175, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1589, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2023, r_ui=3.58086904741548, est=3.56485497324212, details={'was_impossible': False}),
#  Prediction(uid=1, iid=14, r_ui=3.58086904741548, est=3.2980089190835264, details={'was_impossible': False}),
#  Prediction(uid=1, iid=337, r_ui=3.58086904741548, est=4.9636629163791985, details={'was_impossible': False}),
#  Prediction(uid=1, iid=16, r_ui=3.58086904741548, est=2.6301087785465693, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2314, r_ui=3.58086904741548, est=3.2555924457757333, details={'was_impossible': False}),
# ...
#  Prediction(uid=1, iid=1645, r_ui=3.58086904741548, est=3.382494918283939, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2882, r_ui=3.58086904741548, est=3.26596154909008, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2387, r_ui=3.58086904741548, est=3.421976722379147, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2389, r_ui=3.58086904741548, est=2.439579086365166, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2961, r_ui=3.58086904741548, est=3.423555513423044, details={'was_impossible': False}),
#  Prediction(uid=1, iid=553, r_ui=3.58086904741548, est=2.9704121020928165, details={'was_impossible': False}),
#  Prediction(uid=1, iid=628, r_ui=3.58086904741548, est=2.49947378626958, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3261, r_ui=3.58086904741548, est=4.134066721990732, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2605, r_ui=3.58086904741548, est=3.2462690011966138, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1804, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1805, r_ui=3.58086904741548, est=2.4064453853606027, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2391, r_ui=3.58086904741548, est=3.0324858243603345, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2394, r_ui=3.58086904741548, est=3.192617104454018, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3773, r_ui=3.58086904741548, est=3.697091246243832, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1092, r_ui=3.58086904741548, est=2.820588385881085, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1672, r_ui=3.58086904741548, est=4.058889868844764, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2555, r_ui=3.58086904741548, est=2.525613281536443, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2629, r_ui=3.58086904741548, est=2.887205618130553, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2701, r_ui=3.58086904741548, est=3.4458201003518774, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2568, r_ui=3.58086904741548, est=4.310348641567961, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2713, r_ui=3.58086904741548, est=1.315922744614376, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1911, r_ui=3.58086904741548, est=4.189956034061755, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3516, r_ui=3.58086904741548, est=4.85164062188608, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2643, r_ui=3.58086904741548, est=3.3933750986748215, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2720, r_ui=3.58086904741548, est=4.07512902391505, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2722, r_ui=3.58086904741548, est=3.9904284440447464, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2828, r_ui=3.58086904741548, est=4.875603512435984, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2761, r_ui=3.58086904741548, est=3.6269038642998175, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2856, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2369, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2888, r_ui=3.58086904741548, est=3.9136283786311217, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2392, r_ui=3.58086904741548, est=3.5357165400251813, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2975, r_ui=3.58086904741548, est=2.4161546021050855, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1179, r_ui=3.58086904741548, est=3.5784430869544352, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2553, r_ui=3.58086904741548, est=3.4863769208225692, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2554, r_ui=3.58086904741548, est=3.122824575887655, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3932, r_ui=3.58086904741548, est=4.93007687801504, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3863, r_ui=3.58086904741548, est=2.5053441304252786, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1185, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3503, r_ui=3.58086904741548, est=2.995331810439398, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3879, r_ui=3.58086904741548, est=4.559376704336152, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3375, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1779, r_ui=3.58086904741548, est=4.413368175323221, details={'was_impossible': False}),
#  Prediction(uid=1, iid=164, r_ui=3.58086904741548, est=3.4295669401049067, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3457, r_ui=3.58086904741548, est=2.989850133882554, details={'was_impossible': False}),
#  Prediction(uid=1, iid=319, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=247, r_ui=3.58086904741548, est=4.241042163834441, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1428, r_ui=3.58086904741548, est=4.543180954777114, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1284, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2660, r_ui=3.58086904741548, est=2.488251433311957, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2661, r_ui=3.58086904741548, est=2.099088442215011, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2663, r_ui=3.58086904741548, est=3.3959746078805226, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2664, r_ui=3.58086904741548, est=1.5692548536012438, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2667, r_ui=3.58086904741548, est=2.089511019271768, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2668, r_ui=3.58086904741548, est=3.6924934120559616, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3032, r_ui=3.58086904741548, est=2.881965834471345, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3033, r_ui=3.58086904741548, est=4.548105977802969, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2311, r_ui=3.58086904741548, est=3.978289810435142, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2173, r_ui=3.58086904741548, est=4.235655492764792, details={'was_impossible': False}),
#  Prediction(uid=1, iid=198, r_ui=3.58086904741548, est=4.20459790579797, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2752, r_ui=3.58086904741548, est=3.0715291262502538, details={'was_impossible': False}),
#  Prediction(uid=1, iid=340, r_ui=3.58086904741548, est=2.819303710902328, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3700, r_ui=3.58086904741548, est=2.28746142671129, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2901, r_ui=3.58086904741548, est=1.7772193215561083, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3638, r_ui=3.58086904741548, est=2.6900924868171505, details={'was_impossible': False}),
#  Prediction(uid=1, iid=30, r_ui=3.58086904741548, est=4.276010372476168, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1601, r_ui=3.58086904741548, est=2.046966350976415, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3713, r_ui=3.58086904741548, est=1.303060351399599, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2912, r_ui=3.58086904741548, est=3.851401758530571, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3576, r_ui=3.58086904741548, est=4.316984203920428, details={'was_impossible': False}),
#  Prediction(uid=1, iid=503, r_ui=3.58086904741548, est=2.8224853398478413, details={'was_impossible': False}),
#  Prediction(uid=1, iid=293, r_ui=3.58086904741548, est=3.8254278169074354, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1614, r_ui=3.58086904741548, est=4.366268134810246, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2346, r_ui=3.58086904741548, est=2.460994080714311, details={'was_impossible': False}),
#  Prediction(uid=1, iid=942, r_ui=3.58086904741548, est=2.0185809621290653, details={'was_impossible': False}),
#  Prediction(uid=1, iid=446, r_ui=3.58086904741548, est=3.212622607775878, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1624, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3156, r_ui=3.58086904741548, est=4.315041762757156, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2287, r_ui=3.58086904741548, est=3.625778474994714, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2288, r_ui=3.58086904741548, est=3.676873902455627, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3662, r_ui=3.58086904741548, est=4.04511353864943, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3594, r_ui=3.58086904741548, est=3.3343372869825227, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3300, r_ui=3.58086904741548, est=2.7219578585214528, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1206, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1069, r_ui=3.58086904741548, est=3.8378526833565436, details={'was_impossible': False}),
#  Prediction(uid=1, iid=76, r_ui=3.58086904741548, est=4.903247460199792, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2377, r_ui=3.58086904741548, est=2.8919098707179653, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2010, r_ui=3.58086904741548, est=2.1783113559304055, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3827, r_ui=3.58086904741548, est=4.76490143511932, details={'was_impossible': False}),
#  Prediction(uid=1, iid=610, r_ui=3.58086904741548, est=2.8487911964676482, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1077, r_ui=3.58086904741548, est=4.680014313814635, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2526, r_ui=3.58086904741548, est=2.63708502488521, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2527, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2454, r_ui=3.58086904741548, est=3.513891198423898, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2455, r_ui=3.58086904741548, est=2.3134858297389203, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3696, r_ui=3.58086904741548, est=4.623707692280156, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2533, r_ui=3.58086904741548, est=1.0956243262618508, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1301, r_ui=3.58086904741548, est=3.535393917823603, details={'was_impossible': False}),
#  Prediction(uid=1, iid=707, r_ui=3.58086904741548, est=1.7665771954550025, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2613, r_ui=3.58086904741548, est=2.670637227540281, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2542, r_ui=3.58086904741548, est=2.720007678989674, details={'was_impossible': False}),
#  Prediction(uid=1, iid=496, r_ui=3.58086904741548, est=1.9133452060236515, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2549, r_ui=3.58086904741548, est=2.475910606459186, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1748, r_ui=3.58086904741548, est=1, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3927, r_ui=3.58086904741548, est=4.669804688045099, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2116, r_ui=3.58086904741548, est=2.573603838024411, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2117, r_ui=3.58086904741548, est=2.9057282963166853, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2985, r_ui=3.58086904741548, est=3.9325462582622306, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2989, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2123, r_ui=3.58086904741548, est=4.143035391969537, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2052, r_ui=3.58086904741548, est=3.3671873160635886, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2993, r_ui=3.58086904741548, est=4.853403205691008, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1186, r_ui=3.58086904741548, est=3.701143344893382, details={'was_impossible': False}),
#  Prediction(uid=1, iid=222, r_ui=3.58086904741548, est=1.9878460548440917, details={'was_impossible': False}),
#  Prediction(uid=1, iid=158, r_ui=3.58086904741548, est=4.139036617389909, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3877, r_ui=3.58086904741548, est=4.730286605581046, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2139, r_ui=3.58086904741548, est=1.4348039488166022, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3440, r_ui=3.58086904741548, est=2.384995432119033, details={'was_impossible': False}),
#  Prediction(uid=1, iid=737, r_ui=3.58086904741548, est=4.2337980152317245, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2718, r_ui=3.58086904741548, est=3.0684922439729174, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2573, r_ui=3.58086904741548, est=4.6324614845883065, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1918, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=302, r_ui=3.58086904741548, est=1.599276553945242, details={'was_impossible': False}),
#  Prediction(uid=1, iid=232, r_ui=3.58086904741548, est=3.6494069710763752, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2141, r_ui=3.58086904741548, est=2.7143391166843633, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2142, r_ui=3.58086904741548, est=4.74344357016153, details={'was_impossible': False}),
#  Prediction(uid=1, iid=168, r_ui=3.58086904741548, est=4.036787752252432, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2143, r_ui=3.58086904741548, est=2.9529076426239613, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2145, r_ui=3.58086904741548, est=4.041615533193214, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1344, r_ui=3.58086904741548, est=5, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3889, r_ui=3.58086904741548, est=3.9340317540939025, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1275, r_ui=3.58086904741548, est=2.2948480468677044, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3526, r_ui=3.58086904741548, est=4.749667076099532, details={'was_impossible': False}),
#  Prediction(uid=1, iid=313, r_ui=3.58086904741548, est=3.467094750907946, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2153, r_ui=3.58086904741548, est=1.9479337776509826, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2083, r_ui=3.58086904741548, est=3.309128147750215, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2085, r_ui=3.58086904741548, est=4.972421261308524, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2089, r_ui=3.58086904741548, est=3.104299329888638, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2807, r_ui=3.58086904741548, est=4.084323282590047, details={'was_impossible': False}),
#  Prediction(uid=1, iid=2739, r_ui=3.58086904741548, est=2.4537193070911893, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3397, r_ui=3.58086904741548, est=3.8828487592826826, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3398, r_ui=3.58086904741548, est=2.2700243542642697, details={'was_impossible': False}),
#  Prediction(uid=1, iid=3399, r_ui=3.58086904741548, est=4.255343568253865, details={'was_impossible': False}),
#  Prediction(uid=1, iid=327, r_ui=3.58086904741548, est=4.172756915532724, details={'was_impossible': False}),
#  Prediction(uid=1, iid=1367, r_ui=3.58086904741548, est=2.0511981805958657, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# ## Collaborative filtering for movies recommendation

# %% [markdown]
# ### KNN

# %%
algo_kwargs = dict(k=50, sim_options={'name': 'pearson', 'user_based': True, 'verbose' : True})
get_algorithm_report(KNNBasicWithTqdm, trainset, testset, train_loocv, test_loocv, movies_df,
                     target_movie_id='movie_1', target_user_id='user_1', top_k=10,
                    algo_kwargs=algo_kwargs, calc_most_similar=False)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# making predictions:   0%|          | 0/123759 [00:00<?, ?it/s]
# RMSE: 0.9694
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# making predictions:   0%|          | 0/3020 [00:00<?, ?it/s]
# making predictions:   0%|          | 0/10461524 [00:00<?, ?it/s]
# HitRate: 0.00033112582781456954
# Top predictions for user user_1:
# movie_name    genre
# ------------  -------

# %% [markdown]
# The RMSE is better than random but the hit rate is worse. We can also see that the top predictions for user_1 seem even further away than those that were given by the SVD algorithm. In user-based KNN there is no notion of similarity between items, so we won’t calculate the most similar movies to Toy Story (1995) for this algorithm.

# %%
algo_kwargs = dict(k=50, sim_options={'name': 'pearson', 'user_based': False, 'verbose' : True})
get_algorithm_report(KNNBasicWithTqdm, trainset, testset, train_loocv, test_loocv, movies_df,
                     target_movie_id='movie_1', target_user_id='user_1', top_k=10,
                     algo_kwargs=algo_kwargs, calc_most_similar=True)
# Out:
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# making predictions:   0%|          | 0/123759 [00:00<?, ?it/s]
# RMSE: 1.0220
# Computing the pearson similarity matrix...
# Done computing similarity matrix.
# making predictions:   0%|          | 0/3020 [00:00<?, ?it/s]
# making predictions:   0%|          | 0/10461524 [00:00<?, ?it/s]
# HitRate: 0.0
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Study\Ing\2LS\ISA\Projekty\1\isa_mini_projekt_1_hkokin\.venv\lib\site-packages\surprise\trainset.py:155, in Trainset.to_inner_iid(self, riid)
#     154 try:
# --> 155     return self._raw2inner_id_items[riid]
#     156 except KeyError:
#
# KeyError: 'movie_1'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 2
#       1 algo_kwargs = dict(k=50, sim_options={'name': 'pearson', 'user_based': False, 'verbose' : True})
# ----> 2 get_algorithm_report(KNNBasicWithTqdm, trainset, testset, train_loocv, test_loocv, movies_df,
#       3                      target_movie_id='movie_1', target_user_id='user_1', top_k=10,
#       4                      algo_kwargs=algo_kwargs, calc_most_similar=True)
#
# Cell In[13], line 80, in get_algorithm_report(algo_class, trainset, testset, train_loocv, test_loocv, movies_df, target_movie_id, target_user_id, top_k, algo_args, algo_kwargs, calc_most_similar)
#      78 else:
#      79     sims = algo_inst_for_hitrate.sim
# ---> 80 most_similar_movies = get_most_similar_movies(movies_df, sims, train_loocv, target_movie_id, top_k=top_k);
#      81 print(f'Most similar movies to {movies_df.loc[target_movie_id].movie_name}:')
#      82 print(tabulate(most_similar_movies.head(top_k)[['movie_name', 'genre']], headers='keys'))
#
# Cell In[13], line 55, in get_most_similar_movies(movies_df, movie_embeddings, trainset, target_movie_id, top_k)
#      54 def get_most_similar_movies(movies_df, movie_embeddings, trainset, target_movie_id, top_k=10):
# ---> 55     inner_movie_id = trainset.to_inner_iid(target_movie_id)
#      56     sims = cosine_similarity(movie_embeddings, movie_embeddings)
#      57     target_movie_sims_sorted = [trainset.to_raw_iid(x) for x in np.argsort(sims[inner_movie_id])[::-1]]
#
# File D:\Study\Ing\2LS\ISA\Projekty\1\isa_mini_projekt_1_hkokin\.venv\lib\site-packages\surprise\trainset.py:157, in Trainset.to_inner_iid(self, riid)
#     155     return self._raw2inner_id_items[riid]
#     156 except KeyError:
# --> 157     raise ValueError("Item " + str(riid) + " is not part of the trainset.")
#
# ValueError: Item movie_1 is not part of the trainset.

# %% [markdown]
# ## Recommending movies with content-based filtering

# %% [markdown]
# For the content-based filtering we will use KNN-based algorithms in three approaches (two of them item-based and one user-based):
#
# Movie plots (item-based): Create a vector representation of all of the movies based on the plot descriptions. We will do this by first stemming all of the words in the plot description and then applying TF-IDF to vectorize each document. The similarity matrices we will generate will be based on:
# a. Using the complete TF-IDF matrix
#
# b. Using the TF-IDF matrix after feature selection
#
# c. Using the TF-IDF matrix after feature selection and after removing peoples’ names
#
# Movie genres (item-based): **** We will use the movie genres as the only source for recommendations and see how that goes.
# User age+gender (user-based): We will use user data as features for our KNN predictor.

# %%
from surprise import AlgoBase, KNNBasic
from surprise.prediction_algorithms.knns import SymmetricAlgo

class CustomSimKNNAlgorithm(KNNBasic):
  def __init__(self, sim_options, k=40, min_k=1):
    SymmetricAlgo.__init__(self)
    self.sim_options = sim_options
    self.k = k
    self.min_k = min_k

  def fit(self, trainset, similarities): 
    AlgoBase.fit(self, trainset)
    self.sim = similarities
    ub = self.sim_options['user_based']
    self.n_x = self.trainset.n_users if ub else self.trainset.n_items
    self.n_y = self.trainset.n_items if ub else self.trainset.n_users
    self.xr = self.trainset.ur if ub else self.trainset.ir
    self.yr = self.trainset.ir if ub else self.trainset.ur
  
  def test(self, testset, verbose=False):
    # The ratings are translated back to their original scale.
    predictions = [self.predict(uid,
                                iid,
                                r_ui_trans,
                                verbose=verbose)
                    for (uid, iid, r_ui_trans) in tqdm(testset, desc='making predictions')]
    return predictions

# %% [markdown]
# ### Movie plots

# %%
stemmer = SnowballStemmer('english')
movies_df['movie_plot'] = movies_df['movie_plot'].apply(lambda x:' '.join([stemmer.stem(y) for y in x.split()]))

tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies_df['movie_plot'])

tfidf_df = pd.DataFrame(
    tfidf_matrix.todense(),
    columns=tfidf.get_feature_names()
)

# %% [markdown]
# Now, get the results for approach #1 (using the complete TF-IDF matrix). Note that we need a different cosine similarity matrix for the regular trainset and the leave-one-out trainset which is used to calculate hit-rate because they contain different inner ids for each movie.

# %%
item_matrix_all_words_trainset_loocv = get_item_matrix_with_inner_ids(tfidf_matrix.todense(), movies_df, train_loocv)
cosine_sim_all_words_trainset_loocv = cosine_similarity(item_matrix_all_words_trainset_loocv,
                                                        item_matrix_all_words_trainset_loocv)
item_matrix_all_words_trainset = get_item_matrix_with_inner_ids(tfidf_matrix.todense(), movies_df, trainset)
cosine_sim_all_words_trainset = cosine_similarity(item_matrix_all_words_trainset, item_matrix_all_words_trainset)

get_algorithm_report(CustomSimKNNAlgorithm, trainset, testset, train_loocv, test_loocv, movies_df,
                     target_movie_id='movie_1', target_user_id='user_1', top_k=10,
                     algo_kwargs_trainset=dict(similarities=cosine_sim_all_words_trainset, sim_options={'user_based': False}),
                     algo_kwargs_trainset_loocv=dict(similarities=cosine_sim_all_words_trainset_loocv, sim_options={'user_based': False}))

# %% [markdown]
# Worse than collaborative filtering, without a doubt. We also see that the similarity matrix doesn’t really generate meaningful relationships between movies (the only children’s movie which is similar to Toy Story is Toy Story 2). Let’s see if reducing the number of features helps.
